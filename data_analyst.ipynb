# %%
x = [1, 2, 3, 4, 5]
x
# Out:
# [1, 2, 3, 4, 5]

# %%
x = 3 + 5
print(x)
# Out:
# 8

# %%
print(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(y)
#
# NameError: name 'y' is not defined
